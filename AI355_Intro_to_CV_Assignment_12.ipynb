# %% [markdown]
# <a href="https://colab.research.google.com/github/taylan-sen/CIS355_intro_to_ai/blob/main/AI355_Intro_to_CV_Assignment_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intro to Computer Vision
#
# Add your answers below each question line. (Use lecture notes or ChatGPT/google for help.)
#
# Submit completed colab notebook to canvas (i.e. download .ipynb, then submit/upload to canvas)

# %% [markdown]
# ![obamaScale.PNG](data:image/png;base64,...)

# %% [markdown]
# ### Questions
#
# 1. *What are two main goals of Computer Vision?*
#
# 1. *Briefly summarize the knowledge necessary to understand the above Obama image.*
#
# 1. *How is an image typically represented on a computer?*
#
# 1. *What is the numpy module? Why do we use it, i.e. what are its advantages?*
#
# 1. *What is the difference between a vector, matrix, and tensor?*
#
# 1. *Which numpy datatype can be used to represent the above?*
#
# 1. *Use this data type to create in a code cell below: a length 5 vector of zeros, a 3x3 matrix of ones, and a 2x3x4 tensor with 155 in each "voxel".*

# %% [markdown]
# 1. In a code cell below, use the **!wget** command to download a jpg image to the ncolab notebook.(For example: https://www.univstats.com/images/colleges/thumbs/193973-niagara-university.jpg)

# %% [markdown]
# 1. *What is OpenCV? How do you import its python library?*
#
# 1. *Read the image you downloaded into an ndarray using the imread function.*
#
# 1. *Display this image in colab using matplotlib.pyplot's imshow function.*
#
# 1. *Use numpy's zeros function to create a 28 x 28 x 3 tensor of zeros. The create a "+" sign by changing some values in the matrix to 1.*
